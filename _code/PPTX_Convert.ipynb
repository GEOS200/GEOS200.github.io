# %% [markdown]
# Convert a powerpoint to a .qmd file

# %%
from pptx import Presentation
import PIL.Image as Image
import io

Test_File = 'G:\\My Drive\\Sara_Course_Info\\200_Knox\\GEOS 200\\Lectures\\2022 W1/GEOS200-01-2022WT1.pptx'

slide.

# %%
prs = Presentation(Test_File)
for i,slide in enumerate(prs.slides):
    print(i)
    for shape in slide.shapes:
        # if hasattr(shape, "text"):
        #     print(shape.text)
        
        if hasattr(shape, "text"):
            print(shape.text)
            print(shape.text_frame.margin_right)
        # if hasattr(shape, "image"):
        #     A = shape.image
        #     print(i)
        #     print(A.ext)
# Out:
# 0
# Atmospheric Environments
# 91440
# GEOS 200/APBI 244
# 50800
# 1
# Objectives
# 91440
# Welcome by instructor
# Meet your teaching team
# Introduction to GEOS 200/APBI 244
# Introduction to the Canvas page
# Questions?
# The scientific approach
# Standardization, units and conventions
#
# 91440
# 2
# 91440
# 2
# Welcome!
# 91440
# Instructor
#
# Sara Knox
# Assistant Professor
# Department of Geography / Atmospheric Science Program
# 235 - 1984 West Mall
# sara.knox@ubc.ca
# 604-822-2900
#
# Weekly office hour (Zoom or Rm GEOG 235)
#
# Thursdays 11:30 - 12:30
# 91440
# 3
# 91440
# 3
# A little bit about myself
# 91440
# Born and raised in Montreal
# B.Sc. McGill University
# Ph.D. University of California, Berkeley
# Professor at UBC since 2019
# Environmental scientist studying nature-based solutions to climate change
#
# 91440
#
# 50800
# 4
# 91440
# 4
# Your TAs
# 91440
# 5
# 91440
# Darian Ng
# 91440
# Zoe Zhang
# 91440
# Carlie Hughes
# 91440
# 5
# ...

# %%
from pptx import Presentation
prs = Presentation(File)
print("----------------------")
for i,slide in enumerate(prs.slides):
    for shape in slide.shapes:
        if hasattr(shape, "image"):
            A = shape.image
            print(i)
            print(A.ext)
# Out:
# ----------------------
# 0
# jpg
# 2
# png
# 3
# jpg
# 3
# jpg
# 4
# png
# 4
# png
# 4
# png
# 5
# png
# 6
# png
# 7
# png
# 8
# png
# 9
# png
# 10
# png
# 10
# png
# 12
# png
# 13
# png
# 14
# png
# 15
# png
# 16
# png
# 17
# png
# 19
# png
# 20
# png
# 21
# png
# 22
# png
# 22
# png
# 22
# png
# 23
# png

# %%
# A.blob
# import PIL.Image as Image
# import io

# A.filename
for slide in prs.slides:
    for shape in slide.shapes:
        # print(shape)
        if hasattr(shape, "image"):
            A = shape.image
            image = Image.open(io.BytesIO(A.blob))
            image.save(A.filename)

# %%
Topic = '''1:Introduction and course overview
2:Energy (intro.)
2:Energy (cont.)
3:Radiation laws
4:Incoming short-wave radiation
5:Surface geometry and albedo (intro.)
5:Surface geometry and albedo (cont.)
6:Radiative transfer in plant canopies
7:Long-wave radiation
8:Radiation budget of Planet Earth 
9:Net radiation of land surfaces
10:Heat and temperature
11:Heat conduction
12:Thermal admittance (intro.)
12:Thermal admittance (cont.)
13:Atmospheric humidity
14:Laminar boundary layers
15:Temperature of small objects (intro.)
15:Temperature of small objects (cont.)
16:Animal microclimate: basic principles
17:Wind chill and thermal regulation
18:Lapse rates and stability (intro.)
18:Lapse rates and stability
19:Local winds
20:Turbulence and convection (intro.)
20:Turbulence and convection (cont.)
21:Turbulent exchange
22:Wind breaks and wind damage
23:Frost protection
24:Energy balance of crops and forests
25:Evapotranspiration (intro.)
Midterm break
25:Evapotranspiration (cont.)
26:Water balance
27:Photosynthesis and CO2:flux
28:Carbon balance of crops and forests
29:Clouds and cloud formation
30:Winds and global circulation 
31:Synoptic climatology 
32:Climate change (cont.)
Review
Final Examination:(FAQ).'''


Topic = Topic.replace(' (intro.)','').split('\n')
Topics = []
for t in Topic:
    if 'cont.' in t:
        pass
    else:
        Topics.append(t.split(':')[-1])

print(Topics)
# Out:
# ['Introduction and course overview', 'Energy', 'Radiation laws', 'Incoming short-wave radiation', 'Surface geometry and albedo', 'Radiative transfer in plant canopies', 'Long-wave radiation', 'Radiation budget of Planet Earth ', 'Net radiation of land surfaces', 'Heat and temperature', 'Heat conduction', 'Thermal admittance', 'Atmospheric humidity', 'Laminar boundary layers', 'Temperature of small objects', ' basic principles', 'Wind chill and thermal regulation', 'Lapse rates and stability', 'Lapse rates and stability', 'Local winds', 'Turbulence and convection', 'Turbulent exchange', 'Wind breaks and wind damage', 'Frost protection', 'Energy balance of crops and forests', 'Evapotranspiration', 'Midterm break', 'Water balance', 'flux', 'Carbon balance of crops and forests', 'Clouds and cloud formation', 'Winds and global circulation ', 'Synoptic climatology ', 'Review', '(FAQ).']
